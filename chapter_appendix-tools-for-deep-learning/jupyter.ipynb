# %% [markdown]
# <a href="https://colab.research.google.com/github/Vanshree005/learning_ml/blob/main/chapter_appendix-tools-for-deep-learning/jupyter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %% [markdown]
# Import

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd

# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# Fuctional plot

# %%
x_1 = np.linspace(0,5,10)
y_1 = x_1**2
plt.plot(x_1,y_1)
plt.title('Days squared Chart')
plt.xlabel('Days')
plt.ylabel('Days Squared')
plt.show()

# %% [markdown]
# Print multiple plot

# %%
plt.subplot(1,2,1)
plt.plot(x_1,y_1,'r')
plt.subplot(1,2,2)
plt.plot(x_1,y_1,'b')

# %% [markdown]
# using figure objects

# %%
fig_1 = plt.figure(figsize=(5,4),dpi=100)
axes_1 = fig_1.add_axes([0.1,0.1,0.9,0.9])
axes_1.set_xlabel('Days')
axes_1.set_ylabel('Days Squared')
axes_1.set_title('Days Squared Chart')
axes_1.plot(x_1,y_1,label='x/x²')
axes_1.plot(y_1,x_1,label='x²/x')
axes_1.legend(loc=0)

axes_2 = fig_1.add_axes([0.45,0.45,0.4,0.3])
axes_2.set_xlabel('Days')
axes_2.set_ylabel('Days Squared')
axes_2.set_title('Days Squared Chart')
axes_2.plot(x_1,y_1,'g')

axes_2.text(2,40,'message')
# Out:
# Text(2, 40, 'message')

# %% [markdown]
# Sub plots

# %%
fig_2, axes_2 = plt.subplots(figsize=(8,4), nrows=1, ncols=3)
plt.tight_layout()
axes_2[1].set_title('Plot 2')
axes_2[1].set_xlabel('X')
axes_2[1].set_ylabel('X Squared')
axes_2[1].plot(x_1,y_1)

# %% [markdown]
# Apperance options

# %%
fig_3 = plt.figure(figsize=(6,4))
axes_3 = fig_3.add_axes([0,0,1,1])
axes_3.plot(x_1,y_1, color='navy',alpha=0.75,lw=2, ls='-.',marker='o',markersize=7, markerfacecolor='y', markeredgecolor='g', markeredgewidth=4)
axes_3.set_xlim([0,3])
axes_3.set_ylim([0,8])
axes_3.grid(True, color='0.6', dashes=(5,2,1,2))
axes_3.set_facecolor('#FAEBD7')

# %% [markdown]
# save visualization to a file

# %%
fig_3.savefig('3rd_plot.png')

# %% [markdown]
# working with pandas Dataframe

# %%
import pandas as pd
import os

# Sample data for the CSV file
data = {
    'sales': [100, 150, 200, 120, 180],
    'year': [2021, 2022, 2023, 2021, 2022]
}

# Create a Pandas DataFrame from the sample data
sample_df = pd.DataFrame(data)

# Define the file path for the sample CSV file
file_path = 'sample_sales_data.csv'

# Save the DataFrame to a CSV file
sample_df.to_csv(file_path, index=False)

# Now, you can read this CSV file in your code
ics_df = pd.read_csv(file_path)
# ... (rest of your code) ...

ics_df =pd.read_csv('sample_sales_data.csv')
ics_df = ics_df.sort_values(by='sales')

np_arr = ics_df.sort_values(by=['sales'])
x_2 =np_arr['sales'].values
y_2 =np_arr['year'].values
fig_4 =  plt.figure(figsize=(6,4))
axes_4 = fig_4.add_axes([0,0,1,1])

axes_4.set_xlabel('sales')
axes_4.set_ylabel('year')
axes_4.set_title('Sales Chart')
axes_4.plot(x_2,y_2)

axes_4.annotate('netural sales', xy=(160,2022), xytext=(140,2022.50),arrowprops=dict(facecolor='black',shrink=0.05) )
# Out:
# Text(140, 2022.5, 'netural sales')

# %% [markdown]
# teX markup

# %%
fig_5 = plt.figure(figsize=(5,4),dpi=100)
axes_5 = fig_5.add_axes([0.1,0.1,0.9,0.9])

# Corrected the LaTeX command for lambda from \labda to \lambda
axes_5.text(0,23,
            r'$\alpha \beta \sigma \omega \epsilon \mu \pi \theta \lambda$ ')

axes_5.plot(x_1,y_1)

# %% [markdown]
# histrogram

# %%
arr_1 = np.random.randint(1,7,5000)
arr_2 = np.random.randint(1,7,5000)
arr_3 = arr_1 + arr_2
plt.hist(arr_3, bins=11, density=True, stacked=True, color='orange')
#cumulative=True use a cumulative distribution
#histtpe='step' generates a line plot
#orientation='horizontal'
#color='orange'
# Out:
# (array([0.03718, 0.05742, 0.09526, 0.12342, 0.15774, 0.17468, 0.15268,
#         0.1276 , 0.09196, 0.05522, 0.02684]),
#  array([ 2.        ,  2.90909091,  3.81818182,  4.72727273,  5.63636364,
#          6.54545455,  7.45454545,  8.36363636,  9.27272727, 10.18181818,
#         11.09090909, 12.        ]),
#  <BarContainer object of 11 artists>)

# %% [markdown]
# Bar chart

# %%
x = [ 'Nuclear','Hydro','Coal','Gas','Solar','Wind', 'Others']
per_1 = [71, 10, 30, 74, 28 ,14, 3 ]
variance =[8, 3, 1, 3, 1, 2, 1]
plt.barh(x,per_1, color='purple',yerr=variance) #this would give us a horizontal graph
#plt.bar(x,per_1, color='purple',yerr=variance) this would give us a vertical graph
# Out:
# <BarContainer object of 7 artists>

# %%
m_eng = ( 76, 85, 86, 88, 93)
f_eng =(24, 15,14,12, 7)

spc = np.arange(5)

plt.bar(spc, m_eng, width=0.45, label ='Male', edgecolor='k')
plt.bar(spc+ 0.45,f_eng, width=0.45, label ='Female', edgecolor='k')
plt.xticks(spc+ 0.45/2, ( 'Aero', 'chem', 'civil', 'Elec', 'Mech'))
# Out:
# ([<matplotlib.axis.XTick at 0x7f37713bf990>,
#   <matplotlib.axis.XTick at 0x7f3771577150>,
#   <matplotlib.axis.XTick at 0x7f377134cad0>,
#   <matplotlib.axis.XTick at 0x7f377134ef90>,
#   <matplotlib.axis.XTick at 0x7f377150fd90>],
#  [Text(0.225, 0, 'Aero'),
#   Text(1.225, 0, 'chem'),
#   Text(2.225, 0, 'civil'),
#   Text(3.225, 0, 'Elec'),
#   Text(4.225, 0, 'Mech')])

# %%
t_type =['Kind','Elem','Sec', 'Spec']
m_teach =np.array([2, 20, 44, 14])
f_teach=np.array([98, 80, 56, 86])
ind =[x for x , _ in enumerate(t_type)]
plt.bar(ind, m_teach, width=0.45, label ='Male', bottom=f_teach)
plt.bar(ind, f_teach, width=0.45, label ='Female')
plt.legend(loc='lower right')# loc stand gor location

# %% [markdown]
# pie charts

# %%
import random
fig_6 =plt.figure(figsize=(8,5),dpi=100)
axes_6 = fig_6.add_axes([0.1,0.1,0.9,0.9])

types =['Water','Normal','Flying','Grass','Physchic','BUG','Fire','Poison','Ground','Rock','Fighting','dark','Steel','Electric','Dragon','Fairy','Ghost','Ice']
colors =[]
for i in range(18):
  rgb =(random.uniform(0,0.5),random.uniform(0,0.5),random.uniform(0,0.5))
  colors.append(rgb)
explode = [0] * 18
explode[0] = 0.2
poke_num = [100, 80, 60, 50, 40, 30, 70, 20, 90, 10, 5, 15, 25, 35, 45, 55, 65, 75]
wedges , texts ,autotexts = plt.pie(poke_num ,explode=explode, labels=types,colors=colors, autopct='%1.0f%%',shadow=True, startangle=140, textprops=dict(color='w'))
plt.legend(wedges, types, loc='right', bbox_to_anchor=(1,0,0.5,1))

# %%
import datetime
goog_data = pd.read_csv('/content/A.csv') # Changed to 'A.csv'
goog_data_np = goog_data.to_numpy()

# Assuming 'Date' is the first column (index 0) and 'Close' is the fifth column (index 4)
dates = pd.to_datetime(goog_data_np[:, 0])  # Convert the 'Date' column to datetime objects
goog_cp = goog_data_np[:, 4]  # Extract closing prices

# Filter the dates and prices to match your desired range
start_date = datetime.datetime(2020, 5, 20)
end_date = datetime.datetime(2020, 8, 19)
mask = (dates >= start_date) & (dates <= end_date)  # Create a boolean mask for filtering
filtered_dates = dates[mask]
filtered_prices = goog_cp[mask]

# Now you can plot the data within the desired range
fig_7 = plt.figure(figsize=(8, 5))
axes_7 = fig_7.add_axes([0.1, 0.1, 0.9, 0.9])
plt.plot(filtered_dates, filtered_prices)
plt.show()  # Add this line to display the plot if you're not using an interactive environment
